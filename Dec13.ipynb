# %%
using Plots
import Markdown
Base.showable(::MIME"text/markdown", ::Markdown.MD) = false
using IJulia

# %%
x = 0:0.1:2π
# Out:
# 0.0:0.1:6.2

# %%
y = sin.(x)

# %%
plot(x, y)

# %%
ps = plot(x,y,xlim=(0,5),ylim=(-1,1),legend=false,xlabel="x",ylabel="y")

# %%
savefig(ps, "myfigure.pdf")

# %%
# creating a function for the Couette Flow
u(y,Uc,H) = 4*Uc/H^2*y*(H-y)
# Out:
# u (generic function with 1 method)

# %%
H = 0.01
Uc = 1.0
y = range(0,H,length=101)
# Out:
# 0.0:0.0001:0.01

# %%
ps = plot(u.(y,Uc,H), y, xlim=(0,2Uc), ylim=(0,H),
    legend=false, xlabel="u(y)", ylabel="y (m)")

# %%
ps = plot(u.(y,Uc,H)/Uc, y/H, xlim=(0,2), ylim=(0,1),
    legend=false, xlabel="u(y)/Uc", ylabel="y/H (m)")

# %%
def f(vel,velseq, tseq):
    vel[0] = velseq
    vel[1] = 
    return vel
